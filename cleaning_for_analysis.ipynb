# %% [markdown]
# # NIH awards data
# https://exporter.nih.gov/ExPORTER_Catalog.aspx

# %%
import requests, zipfile, io
from bs4 import BeautifulSoup
import os

import pandas as pd
import numpy as np

import cleaning_strings as cln

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
url = 'https://exporter.nih.gov/CSVs/final/RePORTER_PRJ_C_FY2016.zip'
r = requests.get(url).content
z = zipfile.ZipFile(io.BytesIO(r))
z.extractall()

csv = 'RePORTER_PRJ_C_FY2016.csv'
grants_2016_raw = pd.read_csv(csv, encoding = 'latin1')
os.remove(csv)

pd.set_option('display.max_columns', 50)
grants_2016_raw.head(10)
# Out:
#    APPLICATION_ID ACTIVITY ADMINISTERING_IC  APPLICATION_TYPE ARRA_FUNDED  \
# 0         9115627      K23               GM               4.0           N
# 1         9128072      R01               NS               4.0           N
# 2         9056435      D43               TW               4.0           N
# 3         9213716      R01               MH               1.0           N
# 4         8986215      R01               MH               5.0           N
# 5         9090084      P41               EB               4.0           N
# 6         9146706      U01               NS               5.0           N
# 7         9150682      DP5               OD               5.0           N
# 8         9053304      R01               DK               5.0           N
# 9         9359909      ZIA               TR               1.0           N
#
#   AWARD_NOTICE_DATE BUDGET_START  BUDGET_END CFDA_CODE CORE_PROJECT_NUM  \
# 0         7/27/2016     8/1/2016   7/31/2017       859      K23GM104401
# 1         8/15/2016     8/1/2016   7/31/2017       853      R01NS085165
# 2         3/19/2016     3/1/2016   2/28/2017       989      D43TW009310
# 3          9/8/2016     9/9/2016   5/31/2017       242      R01MH111502
# 4         11/5/2015    12/1/2015  11/30/2016       242      R01MH105329
# 5         6/15/2016     6/1/2016   5/31/2017       286      P41EB015871
# 6         9/23/2016     9/1/2016   8/31/2017       853      U01NS094288
# 7          9/9/2016     9/1/2016   8/31/2017       121      DP5OD021391
# 8         1/29/2016     2/1/2016   7/31/2016       847      R01DK105393
# 9               NaN          NaN         NaN       NaN      ZIATR000230
#
#                      ED_INST_TYPE     FOA_NUMBER FULL_PROJECT_NUM  \
# 0             SCHOOLS OF MEDICINE      PA-11-009  4K23GM104401-04
# 1             SCHOOLS OF MEDICINE      PA-11-260  4R01NS085165-04
# 2             SCHOOLS OF MEDICINE     PAR-10-257  4D43TW009310-05
# 3    SCHOOLS OF ARTS AND SCIENCES  RFA-MH-16-775  1R01MH111502-01
# 4             SCHOOLS OF MEDICINE      PA-14-094  5R01MH105329-02
# 5   BIOMED ENGR/COL ENGR/ENGR STA     PAR-10-225  4P41EB015871-30
# 6                             NaN  RFA-NS-15-005  5U01NS094288-02
# 7             SCHOOLS OF MEDICINE  RFA-RM-14-004  5DP5OD021391-02
# 8  SCH OF HOME ECON/HUMAN ECOLOGY      PA-13-302  5R01DK105393-02
# 9                             NaN            NaN  1ZIATR000230-02
#
#                FUNDING_ICs       FUNDING_MECHANISM    FY  \
# 0            NIGMS:194460\  OTHER RESEARCH-RELATED  2016
# 1            NINDS:335781\      Non-SBIR/STTR RPGs  2016
# 2   FIC:146822\NIDA:75000\  OTHER RESEARCH-RELATED  2016
# 3            NIMH:1593922\      Non-SBIR/STTR RPGs  2016
# 4             NIMH:294755\      Non-SBIR/STTR RPGs  2016
# 5            NIBIB:992896\        RESEARCH CENTERS  2016
# 6  NINDS:627714\OD:500000\      Non-SBIR/STTR RPGs  2016
# 7      NCI:399999\NIDCR:1\      Non-SBIR/STTR RPGs  2016
# 8            NIDDK:202611\      Non-SBIR/STTR RPGs  2016
# 9            NCATS:226982\     INTRAMURAL RESEARCH  2016
#
#                                              IC_NAME  \
# 0     NATIONAL INSTITUTE OF GENERAL MEDICAL SCIENCES
# 1  NATIONAL INSTITUTE OF NEUROLOGICAL DISORDERS A...
# 2                       FOGARTY INTERNATIONAL CENTER
# 3                NATIONAL INSTITUTE OF MENTAL HEALTH
# 4                NATIONAL INSTITUTE OF MENTAL HEALTH
# 5  NATIONAL INSTITUTE OF BIOMEDICAL IMAGING AND B...
# 6  NATIONAL INSTITUTE OF NEUROLOGICAL DISORDERS A...
# 7  OFFICE OF THE DIRECTOR, NATIONAL INSTITUTES OF...
# 8  NATIONAL INSTITUTE OF DIABETES AND DIGESTIVE A...
# 9  NATIONAL CENTER FOR ADVANCING TRANSLATIONAL SC...
#
#                                    NIH_SPENDING_CATS            ORG_CITY  \
# 0  Atherosclerosis; Biotechnology; Cardiovascular...            NEW YORK
# 1  Biotechnology; Complementary and Alternative M...           BALTIMORE
# 2  Aging; Behavioral and Social Science; Brain Di...           ANN ARBOR
# 3  Basic Behavioral and Social Science; Behaviora...           CAMBRIDGE
# 4  Acquired Cognitive Impairment; Brain Disorders...         GRAND FORKS
# 5  Bioengineering; Biotechnology; Cancer; Regener...           CAMBRIDGE
# 6  Basic Behavioral and Social Science; Behaviora...  COLD SPRING HARBOR
# 7  Bioengineering; Cancer; Clinical Research; Den...        PHILADELPHIA
# 8                     Diabetes; Nutrition; Obesity;               ITHACA
# 9                            Biotechnology; Cancer;                  NaN
#
#      ORG_COUNTRY                       ORG_DEPT  ORG_DISTRICT   ORG_DUNS  \
# 0  UNITED STATES                       GENETICS          13.0   78861598
# 1  UNITED STATES                 ANESTHESIOLOGY           7.0  188435911
# 2  UNITED STATES                     PSYCHIATRY          12.0   73133571
# 3  UNITED STATES    MICROBIOLOGY/IMMUN/VIROLOGY           5.0   82359691
# 4  UNITED STATES           OTHER BASIC SCIENCES           0.0  102280781
# 5  UNITED STATES        ENGINEERING (ALL TYPES)           7.0    1425594
# 6  UNITED STATES                            NaN           3.0   65968786
# 7  UNITED STATES  RADIATION-DIAGNOSTIC/ONCOLOGY           2.0   42250712
# 8  UNITED STATES                      NUTRITION          23.0  872612445
# 9            NaN                            NaN           NaN        NaN
#
#   ORG_FIPS                                 ORG_NAME ORG_STATE ORG_ZIPCODE  \
# 0       US  ICAHN SCHOOL OF MEDICINE AT MOUNT SINAI        NY   100296574
# 1       US         UNIVERSITY OF MARYLAND BALTIMORE        MD   212011508
# 2       US                   UNIVERSITY OF MICHIGAN        MI   481091276
# 3       US                       HARVARD UNIVERSITY        MA    21385369
# 4       US               UNIVERSITY OF NORTH DAKOTA        ND   582026059
# 5       US    MASSACHUSETTS INSTITUTE OF TECHNOLOGY        MA    21421029
# 6       US            COLD SPRING HARBOR LABORATORY        NY   117242209
# 7       US               UNIVERSITY OF PENNSYLVANIA        PA   191046205
# 8       US                       CORNELL UNIVERSITY        NY   148502820
# 9      NaN                    TRANSLATIONAL SCIENCE       NaN         NaN
#
#                                                  PHR  \
# 0  PUBLIC HEALTH RELEVANCE: Antiplatelet response...
# 1  PUBLIC HEALTH RELEVANCE: Activation of microgl...
# 2  Although recent science has documented the dev...
# 3  Project Narrative To shed light into the basic...
# 4  PUBLIC HEALTH RELEVANCE: The proposed research...
# 5  PUBLIC HEALTH RELEVANCE: The LBRC develops int...
# 6  PUBLIC HEALTH RELEVANCE: All brain functions r...
# 7  PUBLIC HEALTH RELEVANCE: Cancer cells can adap...
# 8  PUBLIC HEALTH RELEVANCE: How protein misfoldin...
# 9                                                NaN
#
#                                               PI_IDS  \
# 0                                         10799126;
# 1                                          7017365;
# 2                       7354078; 1862210 (contact);
# 3              2275890 (contact); 8742217; 6139020;
# 4                       9868481; 2063694 (contact);
# 5                                          1866930;
# 6  9851446; 2291297; 12280974; 9292719 (contact);...
# 7                                         11044822;
# 8                                          9335858;
# 9                                         14380202;
#
#                                             PI_NAMEs  PROGRAM_OFFICER_NAME  \
# 0                           SCOTT, STUART ALEXANDER;     LONG, ROCHELLE M.
# 1                                  POLSTER, BRIAN M;        MORRIS, JILL A
# 2  WALTON, MAUREEN A; ZUCKER, ROBERT ALPERT (cont...   MICHELS, KATHLEEN M
# 3  DULAC, CATHERINE G (contact); REGEV, AVIV ; ZH...     FREUND, MICHELLE
# 4  CHEN, XUESONG ; GEIGER, JONATHAN DAVID (contact);     JOSEPH, JEYMOHAN
# 5                                      SO, PETER T.;  SHABESTARI, BEHROUZ
# 6  EDEN, URI TZVI; FRANK, LOREN M; GANGULI, SURYA...        GNADT, JAMES W
# 7                                   GADE, TERENCE P;      BASAVAPPA, RAVI
# 8                                         QI, LING ;         HAFT, CAROL R
# 9                                   BOXER, MATTHEW ;                   NaN
#
#   PROJECT_START PROJECT_END  \
# 0      8/1/2013   7/31/2017
# 1     9/30/2013   7/31/2018
# 2      7/9/2012   2/28/2017
# 3      9/9/2016   5/31/2019
# 4    12/15/2014  11/30/2019
# 5      6/1/1997   5/31/2017
# 6     9/30/2015   8/31/2018
# 7     9/25/2015   8/31/2020
# 8     4/11/2015   7/31/2016
# 9           NaN         NaN
#
#                                        PROJECT_TERMS  \
# 0  ABCB1 gene; Accounting; acute coronary syndrom...
# 1  Acute; analog; Antioxidants; attenuation; Bind...
# 2  21 year old; Academy; addiction; Address; Alco...
# 3  abstracting; Accounting; Address; Aggressive b...
# 4  Affect; Anti-Retroviral Agents; antiretroviral...
# 5  Area; Automobile Driving; biological research;...
# 6  Adaptive Behaviors; Address; Area; Auditory; b...
# 7  2,4-Dinitrophenol; Acetates; Acids; alpha keto...
# 8  Accounting; Adaptor Signaling Protein; adipocy...
# 9  analog; Antineoplastic Agents; assay developme...
#
#                                        PROJECT_TITLE  SERIAL_NUMBER  \
# 0  The Pharmacogenomic Control of Clopidogrel Res...       104401.0
# 1  Novel Mechanisms of Microglial Neurotoxicity a...        85165.0
# 2  Capacity Building for Lifespan Focused Substan...         9310.0
# 3  In situ transcriptional analysis of brain circ...       111502.0
# 4  Role of novel endolysosome-dependent calcium r...       105329.0
# 5  MIT Laser Biomedical Research Center (P41-RR02...        15871.0
# 6  Computational and circuit mechanisms for infor...        94288.0
# 7  Image-Based Phenotyping of Hepatocellular Carc...        21391.0
# 8  The Role of Sel1L and ER Quality Control in Ad...       105393.0
# 9  Identification of Inhibitors of the Lipid Kina...          230.0
#
#   STUDY_SECTION                                 STUDY_SECTION_NAME  \
# 0           GHD      Genetics of Health and Disease Study Section
# 1          NOMD  Neural Oxidative Metabolism and Death Study Se...
# 2          ZRG1                            Special Emphasis Panel
# 3          ZMH1                            Special Emphasis Panel
# 4          ZRG1                            Special Emphasis Panel
# 5          ZRG1                            Special Emphasis Panel
# 6          ZNS1                            Special Emphasis Panel
# 7          ZRG1                            Special Emphasis Panel
# 8          CADO  Cellular Aspects of Diabetes and Obesity Study...
# 9           NaN                                                NaN
#
#    SUBPROJECT_ID SUFFIX  SUPPORT_YEAR  DIRECT_COST_AMT  INDIRECT_COST_AMT  \
# 0            NaN    NaN           4.0         180500.0            13960.0
# 1            NaN    NaN           4.0         218750.0           117031.0
# 2            NaN    NaN           5.0         209478.0            12344.0
# 3            NaN    NaN           1.0        1077309.0           516613.0
# 4            NaN    NaN           2.0         212500.0            82255.0
# 5            NaN    NaN          30.0         630065.0           362831.0
# 6            NaN    NaN           2.0         945822.0           181892.0
# 7            NaN    NaN           2.0         250000.0           150000.0
# 8            NaN    NaN           2.0         130717.0            71894.0
# 9            NaN    NaN           2.0              NaN                NaN
#
#    TOTAL_COST  TOTAL_COST_SUB_PROJECT
# 0    194460.0                     NaN
# 1    335781.0                     NaN
# 2    221822.0                     NaN
# 3   1593922.0                     NaN
# 4    294755.0                     NaN
# 5    992896.0                     NaN
# 6   1127714.0                     NaN
# 7    400000.0                     NaN
# 8    202611.0                     NaN
# 9    226982.0                     NaN

# %%
grants_2016_raw.shape
# Out:
# (71872, 45)

# %% [markdown]
# # Processing data
#
# ## Basic text processing of column names

# %%
grants_2016 = grants_2016_raw.copy()

grants_2016.columns = grants_2016.columns.str.lower()
grants_2016.head(1)
# Out:
#    application_id activity administering_ic  application_type arra_funded  \
# 0         9115627      K23               GM               4.0           N
#
#   award_notice_date budget_start budget_end cfda_code core_project_num  \
# 0         7/27/2016     8/1/2016  7/31/2017       859      K23GM104401
#
#           ed_inst_type foa_number full_project_num    funding_ics  \
# 0  SCHOOLS OF MEDICINE  PA-11-009  4K23GM104401-04  NIGMS:194460\
#
#         funding_mechanism    fy  \
# 0  OTHER RESEARCH-RELATED  2016
#
#                                           ic_name  \
# 0  NATIONAL INSTITUTE OF GENERAL MEDICAL SCIENCES
#
#                                    nih_spending_cats  org_city    org_country  \
# 0  Atherosclerosis; Biotechnology; Cardiovascular...  NEW YORK  UNITED STATES
#
#    org_dept  org_district  org_duns org_fips  \
# 0  GENETICS          13.0  78861598       US
#
#                                   org_name org_state org_zipcode  \
# 0  ICAHN SCHOOL OF MEDICINE AT MOUNT SINAI        NY   100296574
#
#                                                  phr      pi_ids  \
# 0  PUBLIC HEALTH RELEVANCE: Antiplatelet response...  10799126;
#
#                    pi_names program_officer_name project_start project_end  \
# 0  SCOTT, STUART ALEXANDER;    LONG, ROCHELLE M.      8/1/2013   7/31/2017
#
#                                        project_terms  \
# 0  ABCB1 gene; Accounting; acute coronary syndrom...
#
#                                        project_title  serial_number  \
# 0  The Pharmacogenomic Control of Clopidogrel Res...       104401.0
#
#   study_section                             study_section_name  subproject_id  \
# 0           GHD  Genetics of Health and Disease Study Section             NaN
#
#   suffix  support_year  direct_cost_amt  indirect_cost_amt  total_cost  \
# 0    NaN           4.0         180500.0            13960.0    194460.0
#
#    total_cost_sub_project
# 0                     NaN

# %%
#converts df to lowercase string
grants_2016 = grants_2016.apply(lambda x: x.astype(str).str.lower())
grants_2016.head(1)
# Out:
#   application_id activity administering_ic application_type arra_funded  \
# 0        9115627      k23               gm              4.0           n
#
#   award_notice_date budget_start budget_end cfda_code core_project_num  \
# 0         7/27/2016     8/1/2016  7/31/2017       859      k23gm104401
#
#           ed_inst_type foa_number full_project_num    funding_ics  \
# 0  schools of medicine  pa-11-009  4k23gm104401-04  nigms:194460\
#
#         funding_mechanism    fy  \
# 0  other research-related  2016
#
#                                           ic_name  \
# 0  national institute of general medical sciences
#
#                                    nih_spending_cats  org_city    org_country  \
# 0  atherosclerosis; biotechnology; cardiovascular...  new york  united states
#
#    org_dept org_district  org_duns org_fips  \
# 0  genetics         13.0  78861598       us
#
#                                   org_name org_state org_zipcode  \
# 0  icahn school of medicine at mount sinai        ny   100296574
#
#                                                  phr      pi_ids  \
# 0  public health relevance: antiplatelet response...  10799126;
#
#                    pi_names program_officer_name project_start project_end  \
# 0  scott, stuart alexander;    long, rochelle m.      8/1/2013   7/31/2017
#
#                                        project_terms  \
# 0  abcb1 gene; accounting; acute coronary syndrom...
#
#                                        project_title serial_number  \
# 0  the pharmacogenomic control of clopidogrel res...      104401.0
#
#   study_section                             study_section_name subproject_id  \
# 0           ghd  genetics of health and disease study section            nan
#
#   suffix support_year direct_cost_amt indirect_cost_amt total_cost  \
# 0    nan          4.0        180500.0           13960.0   194460.0
#
#   total_cost_sub_project
# 0                    nan

# %%
#converts 'nan' to NaN
grants_2016.replace(['nan'], np.nan, inplace=True)
grants_2016.head(1)
# Out:
#   application_id activity administering_ic application_type arra_funded  \
# 0        9115627      k23               gm              4.0           n
#
#   award_notice_date budget_start budget_end cfda_code core_project_num  \
# 0         7/27/2016     8/1/2016  7/31/2017       859      k23gm104401
#
#           ed_inst_type foa_number full_project_num    funding_ics  \
# 0  schools of medicine  pa-11-009  4k23gm104401-04  nigms:194460\
#
#         funding_mechanism    fy  \
# 0  other research-related  2016
#
#                                           ic_name  \
# 0  national institute of general medical sciences
#
#                                    nih_spending_cats  org_city    org_country  \
# 0  atherosclerosis; biotechnology; cardiovascular...  new york  united states
#
#    org_dept org_district  org_duns org_fips  \
# 0  genetics         13.0  78861598       us
#
#                                   org_name org_state org_zipcode  \
# 0  icahn school of medicine at mount sinai        ny   100296574
#
#                                                  phr      pi_ids  \
# 0  public health relevance: antiplatelet response...  10799126;
#
#                    pi_names program_officer_name project_start project_end  \
# 0  scott, stuart alexander;    long, rochelle m.      8/1/2013   7/31/2017
#
#                                        project_terms  \
# 0  abcb1 gene; accounting; acute coronary syndrom...
#
#                                        project_title serial_number  \
# 0  the pharmacogenomic control of clopidogrel res...      104401.0
#
#   study_section                             study_section_name subproject_id  \
# 0           ghd  genetics of health and disease study section            NaN
#
#   suffix support_year direct_cost_amt indirect_cost_amt total_cost  \
# 0    NaN          4.0        180500.0           13960.0   194460.0
#
#   total_cost_sub_project
# 0                    NaN

# %%
#Use this csv to clean PI information
grants_2016.to_csv('grants_all.csv', compression = 'gzip')

# %% [markdown]
# ## Selecting columns for analysis
# There are a total of 45 columns, which may contain redundant or unnecessary information.

# %%
pd.set_option('display.max_colwidth', 5000)
col_info = pd.read_csv('grant_col_info_all.csv')
col_info[:9]
# Out:
#                                             column_name  \
# 0                                        application_id
# 1                                              activity
# 2                                    administering_ic
# 3                                      application_type
# 4                                           arra_funded
# 5                                   award_notice_date
# 6                                        budget_start
# 7                                          budget_end
# 8                                           cfda_code
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       descriptions
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            A unique identifier of the project record in the  ExPORTER database.
# 1                                                                                                                                                 A 3-character code identifying the grant, contract, or  intramural activity through which a project is supported. Within each  funding mechanism , NIH  uses 3-character activity codes (e.g., F32, K08, P01, R01, T32, etc.) to  differentiate the wide variety of research-related programs NIH supports. A  comprehensive  list of activity codes  for grants and cooperative agreements may be found  on the  Types of Grant  Programs  Web page. RePORTER also includes R&D contracts (activity  codes beginning with the letter N) and intramural projects (beginning with the  letter Z).
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Administering Institute or Center - A two-character  code to designate the agency,NIH Institute, or Center administering the  grant. See  Institute/Center code  definitions
# 3  A one-digit code to identify the type of  application funded: 1 = New application                              2 = Competing continuation (also, competing renewal)                              3 = Application for additional (supplemental) support.  There are two kinds of type   3competing revisions (which are peer-reviewed and administrative supplements)                              4 = Competing extension for an R37 award or first  non-competing year of a Fast Track SBIR/STTR award                              5 = Non-competing continuation                              7 = Change of grantee institution                              9 = Change of NIH awarding Institute or Division (on a  competing continuation)
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           “Y”  indicates a project supported by funds appropriated through the American  Recovery and Reinvestment Act of 2009.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Award notice date or Notice of Grant Award (NGA) is a legally binding document stating the government has obligated funds and which defines the period of support and the terms and conditions of award.\r\n
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         The date when a  project’s funding for a particular fiscal year begins.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            The date when a  project’s funding for a particular fiscal year ends.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Federal programs are assigned a number in the Catalog of Federal Domestic Assistance (CFDA), which is referred to as the "CFDA code." The CFDA database helps the Federal government track all programs it has domestically funded. \r\n

# %% [markdown]
# To remove (initial): 5-8, redundant information

# %%
to_drop = ['award_notice_date', 'budget_start', 'budget_end', 'cfda_code']
grants_2016 = grants_2016.drop(to_drop, axis = 1)

# %%
col_info[9:18]
# Out:
#              column_name  \
# 9     core_project_num
# 10        ed_inst_type
# 11          foa_number
# 12    full_project_num
# 13       funding_ic(s)
# 14  funding_mechanism
# 15                    fy
# 16             ic_name
# 17   nih_spending_cats
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                      descriptions
# 9                                                                                                                  An identifier for each research project, used to associate the project with publication and patent records.  This identifier is not specific to any particular year of the project.  It consists of the project activity code, administering IC, and serial number (a concatenation of Activity, Administering_IC, and Serial_Number).  \r\n
# 10                                                                                                                                                                                                                                        Generic name for the grouping of components across an institution who has applied for or receives NIH funding. The official name as used by NIH is Major Component Combining Name. \r\n
# 11  The  number of the funding opportunity announcement, if any, under which the project  application was solicited. Funding opportunity announcements may be  categorized as program announcements, requests for applications, notices of  funding availability, solicitations, or other names depending on the agency and  type of program. Funding opportunity announcements can be found at  Grants.gov/FIND  and in the  NIH Guide for Grants and  Contracts
# 12                                                                                                                                            Commonly referred to as a grant number,  intramural project, or contract number.  For grants, this unique  identification number is composed of the type code, activity code, Institute/Center  code, serial number, support year, and (optional) a suffix code to designate  amended applications and supplements.
# 13                                                                             The NIH Institute  or Center(s) providing funding for a project are designated by their acronyms  (see  Institute/Center acronyms ).  Each funding IC is followed by a colon (:) and the amount of funding provided  for the fiscal year by that IC. Multiple ICs are separated by semicolons  (;). Project funding information is available only for NIH, CDC, and FDA projects .
# 14                               The major  mechanism  categories used in NIH Budget mechanism tables for the President’s budget. Extramural research awards are divided into three main funding mechanisms: grants, cooperative agreements and contracts. A funding mechanism is the type of funded application or transaction used at the NIH. Within each funding mechanism NIH includes programs. Programs can be further refined by specific activity codes.
# 15                                                                                                                                                                                                                                                                                                                                                                                        The fiscal year appropriation from which project funds were  obligated.
# 16                                                                                                                                                                                                                                                                                                                                                                                                 Full name of the administering agency, Institute, or  Center.
# 17                                          Congressionally-mandated reporting  categories into which NIH projects are categorized. Available for fiscal  years 2008 and later. Each project’s spending category designations for  each fiscal year are made available the following year as part of the next  President’s Budget request. See the  Research,  Condition, and Disease Categorization System  for more information on the  categorization process.

# %% [markdown]
# To remove: 9 (may add in later if correlating with publications), 10-12, 16; also 2 (redundant with funding_ics)

# %%
to_drop2 = ['administering_ic', 'core_project_num', 'ed_inst_type', 'foa_number', 'full_project_num', 'ic_name']
grants_2016 = grants_2016.drop(to_drop2, axis = 1)

# %%
col_info[18:27]
# Out:
#             column_name  \
# 18           org_city
# 19        org_country
# 20             org_dept
# 21         org_district
# 22             org_duns
# 23             org_fips
# 24             org_name
# 25            org_state
# 26          org_zipcode
#
#                                                                                                                                                                                                                                                                                              descriptions
# 18                                                                           The city in which the  business office of the grantee organization or contractor is located.  Note  that this may be different from the research performance site.  For all NIH intramural projects, Bethesda, MD is  used.
# 19                                                                                                                                 The country in which  the business office of the grantee organization or contractor is located.   Note that this may be different from the research performance site.
# 20                                                                                                     The departmental affiliation of the contact principal  investigator for a project, using a standardized categorization of departments.   Names are available only for medical school departments.
# 21                                                                                                                  The congressional district in which the business office  of the grantee organization or contractor is located.  Note that this may  be different from the research performance site.
# 22    This field may contain multiple DUNS Numbers separated by a semi-colon. The Data Universal Numbering System is a unique nine-digit number assigned by Dun and Bradstreet Information Services, recognized as the universal standard for identifying and keeping track of business worldwide. \r\n
# 23                                                                                                                                                                                The country code of the grantee organization or contractor  as defined in the Federal Information Processing Standard.
# 24                                                                                                               The name of the educational institution, research organization, business, or government agency receiving funding for the grant, contract, cooperative agreement, or intramural project.
# 25                                                                                                                                   The state in which the business office of the grantee  organization or contractor is located.  Note that this may be different from  the research performance site.
# 26                                                                                                                                 The zip code in which the business office of the grantee  organization or contractor is located.  Note that this may be different  from the research performance site.

# %% [markdown]
# All redundant: 18, 20-23, 25
#
# Also remove 19, 24, 26; these will be added again later.

# %%
to_drop3 = ['org_city', 'org_country', 'org_dept', 'org_district', 'org_duns', 'org_fips', 'org_name', 'org_state', 'org_zipcode']
grants_2016 = grants_2016.drop(to_drop3, axis = 1)

# %%
col_info[27:36]
# Out:
#                column_name  \
# 27                   phr
# 28                pi_id(s)
# 29              pi_name(s)
# 30  program_officer_name
# 31         project_start
# 32           project_end
# 33         project_terms
# 34         project_title
# 35          serial_number
#
#                                                                                                                                                                                                                                                                                                   descriptions
# 27                                                                                                                                                                                      Submitted as part of a grant application, this  statement articulates a project's potential to improve public health.
# 28                                                                                                                A unique identifier for each of the project  Principal Investigators.  Each PI in the RePORTER database has a unique  identifier that is constant from project to project and year to year.
# 29                                                                                                                                                                                               The name(s) of the Principal Investigator(s)  designated by the organization to direct the research project.
# 30                                                                                                                                                                       An Institute staff member who coordinates the substantive aspects of a contract from planning the request for proposal to oversight.
# 31                                                                                                                                                                                      The start date of  a project.  For subprojects of a  multi-project grant, this is the start date of the parent award.
# 32  The current end date  of the project, including any future years for which commitments have been made.  For subprojects of a multi-project grant,  this is the end date of the parent award.  Upon competitive renewal of a  grant, the project end date is extended by the length of the renewal  award.
# 33                                  Prior to fiscal year 2008, these were thesaurus  terms assigned by NIH CRISP indexers.  For projects funded in fiscal year  2008 and later, these are concepts that are mined from the project's title,  abstract, and specific aims using an automated text mining tool.
# 34                                                                                                                                                                                                                                          Title of the funded grant, contract, or intramural  (sub)project.
# 35                                                                                                                                                                                                                A six-digit number assigned in serial number order within  each administering organization.

# %% [markdown]
# 27 (phr): maybe later for text analysis, too complex for initial analysis; 29, 34, 35

# %%
to_drop4 = ['phr', 'pi_names', 'program_officer_name', 'project_title', 'serial_number']
grants_2016 = grants_2016.drop(to_drop4, axis = 1)

# %%
col_info[36:]
# Out:
#                  column_name  \
# 36           study_section
# 37       study_section_name
# 38           subproject_id
# 39                  suffix
# 40            support_year
# 41         direct_cost_amt
# 42       indirect_cost_amt
# 43              total_cost
# 44  total_cost_sub_project
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      descriptions
# 36                                                                                                                                                                                                                                                                                                                                                                                                                 A designator of the legislatively-mandated panel of  subject matter experts that reviewed the research grant application for  scientific and technical merit.
# 37                                                                                                                                                                                                                                                                                                                  The full name of a regular standing Study  Section that reviewed the research grant application for scientific and  technical merit.  Applications reviewed by panels other than regular  standing study sections are designated by “Special Emphasis Panel.”
# 38                                                                                                                                                                                                                                                                                                                                                                                                                                                                             A unique numeric designation assigned to  subprojects of a “parent” multi-project research grant.
# 39                                                                                                                                                                                                                                                                                                                                      A suffix to the grant application number that includes the  letter "A" and a serial number to identify an amended version of an  original application and/or the letter "S" and serial number  indicating a supplement to the project. .
# 40                                                                                                                                                                                                                                                                                                                                                                                                               The year of support  for a project, as shown in the full project number.  For example, a project with number  5R01GM0123456-04 is in its fourth year of support.
# 41                                                                                                                                                                                                                                                                                                                                   Total  indirect cost  funding for a project from all NIH Institute and Centers for a given fiscal year.  Costs are available only for NIH awards funded in FY 2012 and onward. Indirect cost amounts are not available for SBIR/STTR awards.
# 42                                                                                                                                                                                                                                                                                                                                   Total  indirect cost  funding for a project from all NIH Institute and Centers for a given fiscal year.  Costs are available only for NIH awards funded in FY 2012 and onward. Indirect cost amounts are not available for SBIR/STTR awards.
# 43  Total project funding from all NIH Institute and Centers for a given fiscal year. Costs are available only for: NIH, CDC, and FDA grant awards (only the parent record of multi-project grants). -NIH intramural projects (activity codes beginning with “Z”) in FY 2007 and later fiscal years. -NIH contracts (activity codes beginning with “N”) .   For multi-project grants, Total_Cost includes funding for all of the constituent subprojects.  This field will be blank on subproject records; the total cost of each subproject is found in Total_Cost_Sub_Project .
# 44                                                                                                                                                                                                                                                                                                                                                                                                  Applies to subproject  records only.  Total funding for a subproject from all NIH  Institute and Centers for a given fiscal year.  Costs are available only for NIH awards.

# %% [markdown]
# 37 (redundant with 36, can always look up)

# %%
#check number of subprojects
#grants_2016.shape
#subproject_cols = ['subproject_id', 'suffix', 'total_cost_sub_project']
#grants_2016[subproject_cols].isnull().sum()

# %%
grants_2016 = grants_2016.drop(['study_section_name', 'subproject_id', 'suffix'], axis = 1)

# %%
pd.set_option('display.max_colwidth', 50)
grants_2016.head()
# Out:
#   application_id activity application_type arra_funded  \
# 0        9115627      k23              4.0           n
# 1        9128072      r01              4.0           n
# 2        9056435      d43              4.0           n
# 3        9213716      r01              1.0           n
# 4        8986215      r01              5.0           n
#
#               funding_ics       funding_mechanism    fy  \
# 0           nigms:194460\  other research-related  2016
# 1           ninds:335781\      non-sbir/sttr rpgs  2016
# 2  fic:146822\nida:75000\  other research-related  2016
# 3           nimh:1593922\      non-sbir/sttr rpgs  2016
# 4            nimh:294755\      non-sbir/sttr rpgs  2016
#
#                                    nih_spending_cats  \
# 0  atherosclerosis; biotechnology; cardiovascular...
# 1  biotechnology; complementary and alternative m...
# 2  aging; behavioral and social science; brain di...
# 3  basic behavioral and social science; behaviora...
# 4  acquired cognitive impairment; brain disorders...
#
#                                   pi_ids project_start project_end  \
# 0                             10799126;       8/1/2013   7/31/2017
# 1                              7017365;      9/30/2013   7/31/2018
# 2           7354078; 1862210 (contact);       7/9/2012   2/28/2017
# 3  2275890 (contact); 8742217; 6139020;       9/9/2016   5/31/2019
# 4           9868481; 2063694 (contact);     12/15/2014  11/30/2019
#
#                                        project_terms study_section  \
# 0  abcb1 gene; accounting; acute coronary syndrom...           ghd
# 1  acute; analog; antioxidants; attenuation; bind...          nomd
# 2  21 year old; academy; addiction; address; alco...          zrg1
# 3  abstracting; accounting; address; aggressive b...          zmh1
# 4  affect; anti-retroviral agents; antiretroviral...          zrg1
#
#   support_year direct_cost_amt indirect_cost_amt total_cost  \
# 0          4.0        180500.0           13960.0   194460.0
# 1          4.0        218750.0          117031.0   335781.0
# 2          5.0        209478.0           12344.0   221822.0
# 3          1.0       1077309.0          516613.0  1593922.0
# 4          2.0        212500.0           82255.0   294755.0
#
#   total_cost_sub_project
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %% [markdown]
# ### More cleaning of columns

# %% [markdown]
# Convert strings to numeric and dates

# %%
def convert_column(df, list_of_names, function):
    '''
    Converts df column values from x to 'function'.
    Function = numeric: pd.to_numeric()
    Function = date: pd.to_datetime()
    Takes a df and a list with the column names.
    Returns df.
    '''
    for name in list_of_names:
        if function == 'numeric':
            df[name] = pd.to_numeric(df[name])
        elif function == 'date':
            df[name] = pd.to_datetime(df[name], errors = 'coerce')
    return df

numeric_cols = ['direct_cost_amt', 'indirect_cost_amt', 'total_cost', 'total_cost_sub_project']
grants_2016 = convert_column(grants_2016, numeric_cols, function = 'numeric')

date_cols = ['project_start', 'project_end']
grants_2016 = convert_column(grants_2016, date_cols, function = 'date')


grants_2016.head(1)
# Out:
#   application_id activity application_type arra_funded    funding_ics  \
# 0        9115627      k23              4.0           n  nigms:194460\
#
#         funding_mechanism    fy  \
# 0  other research-related  2016
#
#                                    nih_spending_cats      pi_ids  \
# 0  atherosclerosis; biotechnology; cardiovascular...  10799126;
#
#   project_start project_end  \
# 0    2013-08-01  2017-07-31
#
#                                        project_terms study_section  \
# 0  abcb1 gene; accounting; acute coronary syndrom...           ghd
#
#   support_year  direct_cost_amt  indirect_cost_amt  total_cost  \
# 0          4.0         180500.0            13960.0    194460.0
#
#    total_cost_sub_project
# 0                     NaN

# %% [markdown]
# ## Extract funding institute information

# %%
grants_2016['funding_ics'] = grants_2016['funding_ics'].astype(str)
institute_funds = pd.DataFrame([grants_2016['application_id'], grants_2016['funding_ics']]).T

# %% [markdown]
# ## Splitting individual PIs when more than one is listed on a grant
# Split grants with multiple PIs so that each row only has a single PI listed. This will allow analysis on funding per individual and per institution.

# %%
col_list = ['nih_spending_cats', 'pi_ids', 'project_terms']
grants_2016 = cln.strip_series(grants_2016, col_list, strip = '; ')
grants_2016 = cln.split_rows_pis(grants_2016, col_name = 'pi_ids')

# %% [markdown]
# More cleaning

# %%
grants_2016 = cln.strip_series(grants_2016, ['pi_ids'])
grants_2016 = cln.strip_series(grants_2016, ['pi_ids'], strip = ' ')
grants_2016.head()
# Out:
#   application_id activity application_type arra_funded full_project_num  \
# 0        9115627      k23              4.0           n  4k23gm104401-04
# 1        9128072      r01              4.0           n  4r01ns085165-04
# 2        9056435      d43              4.0           n  4d43tw009310-05
# 2        9056435      d43              4.0           n  4d43tw009310-05
# 3        9213716      r01              1.0           n  1r01mh111502-01
#
#               funding_ics       funding_mechanism    fy  \
# 0           nigms:194460\  other research-related  2016
# 1           ninds:335781\      non-sbir/sttr rpgs  2016
# 2  fic:146822\nida:75000\  other research-related  2016
# 2  fic:146822\nida:75000\  other research-related  2016
# 3           nimh:1593922\      non-sbir/sttr rpgs  2016
#
#                                    nih_spending_cats project_start  \
# 0  atherosclerosis; biotechnology; cardiovascular...    2013-08-01
# 1  biotechnology; complementary and alternative m...    2013-09-30
# 2  aging; behavioral and social science; brain di...    2012-07-09
# 2  aging; behavioral and social science; brain di...    2012-07-09
# 3  basic behavioral and social science; behaviora...    2016-09-09
#
#   project_end                                      project_terms  \
# 0  2017-07-31  abcb1 gene; accounting; acute coronary syndrom...
# 1  2018-07-31  acute; analog; antioxidants; attenuation; bind...
# 2  2017-02-28  21 year old; academy; addiction; address; alco...
# 2  2017-02-28  21 year old; academy; addiction; address; alco...
# 3  2019-05-31  abstracting; accounting; address; aggressive b...
#
#   study_section support_year  direct_cost_amt  indirect_cost_amt  total_cost  \
# 0           ghd          4.0         180500.0            13960.0    194460.0
# 1          nomd          4.0         218750.0           117031.0    335781.0
# 2          zrg1          5.0         209478.0            12344.0    221822.0
# 2          zrg1          5.0         209478.0            12344.0    221822.0
# 3          zmh1          1.0        1077309.0           516613.0   1593922.0
#
#    total_cost_sub_project    pi_ids
# 0                     NaN  10799126
# 1                     NaN   7017365
# 2                     NaN   7354078
# 2                     NaN   1862210
# 3                     NaN   2275890

# %% [markdown]
# Split grant totals by number of associated PIs (assumption is that all PIs on a grant receive the same amount of money).

# %%
#divide cost columns by # of times the application_id occurs
pi_per_grant = pd.DataFrame(grants_2016['application_id'].value_counts())
pi_per_grant = pi_per_grant.reset_index()
pi_per_grant.columns = ['application_id', 'num_pis']

#Match application IDs in grants_2016 and pi_per_grant
#Divide the 3 cost columns by 
grants_2016 = pd.merge(grants_2016, pi_per_grant, on = 'application_id')

# %%
grants_2016.head()
# Out:
#   application_id activity application_type arra_funded full_project_num  \
# 0        9115627      k23              4.0           n  4k23gm104401-04
# 1        9128072      r01              4.0           n  4r01ns085165-04
# 2        9056435      d43              4.0           n  4d43tw009310-05
# 3        9056435      d43              4.0           n  4d43tw009310-05
# 4        9213716      r01              1.0           n  1r01mh111502-01
#
#               funding_ics       funding_mechanism    fy  \
# 0           nigms:194460\  other research-related  2016
# 1           ninds:335781\      non-sbir/sttr rpgs  2016
# 2  fic:146822\nida:75000\  other research-related  2016
# 3  fic:146822\nida:75000\  other research-related  2016
# 4           nimh:1593922\      non-sbir/sttr rpgs  2016
#
#                                    nih_spending_cats project_start  \
# 0  atherosclerosis; biotechnology; cardiovascular...    2013-08-01
# 1  biotechnology; complementary and alternative m...    2013-09-30
# 2  aging; behavioral and social science; brain di...    2012-07-09
# 3  aging; behavioral and social science; brain di...    2012-07-09
# 4  basic behavioral and social science; behaviora...    2016-09-09
#
#   project_end                                      project_terms  \
# 0  2017-07-31  abcb1 gene; accounting; acute coronary syndrom...
# 1  2018-07-31  acute; analog; antioxidants; attenuation; bind...
# 2  2017-02-28  21 year old; academy; addiction; address; alco...
# 3  2017-02-28  21 year old; academy; addiction; address; alco...
# 4  2019-05-31  abstracting; accounting; address; aggressive b...
#
#   study_section support_year  direct_cost_amt  indirect_cost_amt  total_cost  \
# 0           ghd          4.0         180500.0            13960.0    194460.0
# 1          nomd          4.0         218750.0           117031.0    335781.0
# 2          zrg1          5.0         209478.0            12344.0    221822.0
# 3          zrg1          5.0         209478.0            12344.0    221822.0
# 4          zmh1          1.0        1077309.0           516613.0   1593922.0
#
#    total_cost_sub_project    pi_ids  num_pis
# 0                     NaN  10799126        1
# 1                     NaN   7017365        1
# 2                     NaN   7354078        2
# 3                     NaN   1862210        2
# 4                     NaN   2275890        3

# %%
def divide_by_column(df, col_list = ['direct_cost_amt', 'indirect_cost_amt', 'total_cost'], divide_by = 'num_pis'):
    '''
    
    Divide df columns by value in another column
    
    '''
    for col in col_list:
        df[col] = round(df[col] / df[divide_by])
    return df

grants_2016 = divide_by_column(grants_2016)

# %%
grants_2016.head()
# Out:
#   application_id activity application_type arra_funded full_project_num  \
# 0        9115627      k23              4.0           n  4k23gm104401-04
# 1        9128072      r01              4.0           n  4r01ns085165-04
# 2        9056435      d43              4.0           n  4d43tw009310-05
# 3        9056435      d43              4.0           n  4d43tw009310-05
# 4        9213716      r01              1.0           n  1r01mh111502-01
#
#               funding_ics       funding_mechanism    fy  \
# 0           nigms:194460\  other research-related  2016
# 1           ninds:335781\      non-sbir/sttr rpgs  2016
# 2  fic:146822\nida:75000\  other research-related  2016
# 3  fic:146822\nida:75000\  other research-related  2016
# 4           nimh:1593922\      non-sbir/sttr rpgs  2016
#
#                                    nih_spending_cats project_start  \
# 0  atherosclerosis; biotechnology; cardiovascular...    2013-08-01
# 1  biotechnology; complementary and alternative m...    2013-09-30
# 2  aging; behavioral and social science; brain di...    2012-07-09
# 3  aging; behavioral and social science; brain di...    2012-07-09
# 4  basic behavioral and social science; behaviora...    2016-09-09
#
#   project_end                                      project_terms  \
# 0  2017-07-31  abcb1 gene; accounting; acute coronary syndrom...
# 1  2018-07-31  acute; analog; antioxidants; attenuation; bind...
# 2  2017-02-28  21 year old; academy; addiction; address; alco...
# 3  2017-02-28  21 year old; academy; addiction; address; alco...
# 4  2019-05-31  abstracting; accounting; address; aggressive b...
#
#   study_section support_year  direct_cost_amt  indirect_cost_amt  total_cost  \
# 0           ghd          4.0         180500.0            13960.0    194460.0
# 1          nomd          4.0         218750.0           117031.0    335781.0
# 2          zrg1          5.0         104739.0             6172.0    110911.0
# 3          zrg1          5.0         104739.0             6172.0    110911.0
# 4          zmh1          1.0         359103.0           172204.0    531307.0
#
#    total_cost_sub_project    pi_ids  num_pis
# 0                     NaN  10799126        1
# 1                     NaN   7017365        1
# 2                     NaN   7354078        2
# 3                     NaN   1862210        2
# 4                     NaN   2275890        3

# %% [markdown]
# ## Add organization information
#
# Import pi_info.csv, which contains the necessary information.

# %%
cols_import = ['pi_ids', 'org_name', 'org_country', 'org_zipcode']
pi_info = pd.read_csv('pi_info.csv', compression = 'gzip', usecols = cols_import, dtype = {'pi_ids':str})
pi_info.head()
# Out:
#      pi_ids                                 org_name    org_country  \
# 0  10799126  icahn school of medicine at mount sinai  united states
# 1   7017365         university of maryland baltimore  united states
# 2   1862210                   university of michigan  united states
# 3   1866930    massachusetts institute of technology  united states
# 4   9851446            cold spring harbor laboratory  united states
#
#   org_zipcode
# 0   100296574
# 1   212011508
# 2   481091276
# 3   021421029
# 4   117242209

# %% [markdown]
# Merge the two dataframes so the information is listed together.

# %%
grants_2016 = pd.merge(grants_2016, pi_info, left_on = 'pi_ids', right_on = 'pi_ids', how = 'left')

# %% [markdown]
# ## Cost of grants (funds)
# There are 4 cost columns. Indirect and direct costs sum to total costs or to total subproject costs. Drop indirect and direct costs columns and combine the total costs into one column (costs are either listed as total cost or total subproject cost).

# %%
grants_2016 = grants_2016.drop(['direct_cost_amt', 'indirect_cost_amt'], axis = 1)
grants_2016['total_cost'].fillna(grants_2016['total_cost_sub_project'], inplace = True)
del grants_2016['total_cost_sub_project']

# %%
grants_2016.rename(columns = {'total_cost':'funds'}, inplace = True)
grants_2016.head()
# Out:
#   application_id activity application_type arra_funded full_project_num  \
# 0        9115627      k23              4.0           n  4k23gm104401-04
# 1        9128072      r01              4.0           n  4r01ns085165-04
# 2        9056435      d43              4.0           n  4d43tw009310-05
# 3        9056435      d43              4.0           n  4d43tw009310-05
# 4        9213716      r01              1.0           n  1r01mh111502-01
#
#               funding_ics       funding_mechanism    fy  \
# 0           nigms:194460\  other research-related  2016
# 1           ninds:335781\      non-sbir/sttr rpgs  2016
# 2  fic:146822\nida:75000\  other research-related  2016
# 3  fic:146822\nida:75000\  other research-related  2016
# 4           nimh:1593922\      non-sbir/sttr rpgs  2016
#
#                                    nih_spending_cats project_start  \
# 0  atherosclerosis; biotechnology; cardiovascular...    2013-08-01
# 1  biotechnology; complementary and alternative m...    2013-09-30
# 2  aging; behavioral and social science; brain di...    2012-07-09
# 3  aging; behavioral and social science; brain di...    2012-07-09
# 4  basic behavioral and social science; behaviora...    2016-09-09
#
#   project_end                                      project_terms  \
# 0  2017-07-31  abcb1 gene; accounting; acute coronary syndrom...
# 1  2018-07-31  acute; analog; antioxidants; attenuation; bind...
# 2  2017-02-28  21 year old; academy; addiction; address; alco...
# 3  2017-02-28  21 year old; academy; addiction; address; alco...
# 4  2019-05-31  abstracting; accounting; address; aggressive b...
#
#   study_section support_year     funds    pi_ids  num_pis  \
# 0           ghd          4.0  194460.0  10799126        1
# 1          nomd          4.0  335781.0   7017365        1
# 2          zrg1          5.0  110911.0   7354078        2
# 3          zrg1          5.0  110911.0   1862210        2
# 4          zmh1          1.0  531307.0   2275890        3
#
#                                   org_name    org_country org_zipcode
# 0  icahn school of medicine at mount sinai  united states   100296574
# 1         university of maryland baltimore  united states   212011508
# 2                   university of michigan  united states   481091276
# 3                   university of michigan  united states   481091276
# 4                       harvard university  united states   021385369

# %% [markdown]
# Save dataframe to csv

# %%
grants_2016.to_csv('for_analysis.csv', index = False, compression = 'gzip')

# %% [markdown]
# ## Institute funds per grant

# %%
institute_funds.head()
# Out:
#   application_id             funding_ics
# 0        9115627           nigms:194460\
# 1        9128072           ninds:335781\
# 2        9056435  fic:146822\nida:75000\
# 3        9213716           nimh:1593922\
# 4        8986215            nimh:294755\

# %% [markdown]
# Drop final \

# %%
institute_funds['funding_ics'] = institute_funds['funding_ics'].str.strip('\ ')

# %% [markdown]
# Split funding institute name and funding amount into individual cells in a df

# %%
ics = list(institute_funds['funding_ics'])
for i in range(len(ics)):
    ics[i] = ics[i].split('\\')
#ics

for i in range(len(ics)):
    for j in range(len(ics[i])):
        ics[i][j] = ics[i][j].split(':')

ics
# Out:
# [[['nigms', '194460']],
#  [['ninds', '335781']],
#  [['fic', '146822'], ['nida', '75000']],
#  [['nimh', '1593922']],
#  [['nimh', '294755']],
#  [['nibib', '992896']],
#  [['ninds', '627714'], ['od', '500000']],
#  [['nci', '399999'], ['nidcr', '1']],
#  [['niddk', '202611']],
#  [['ncats', '226982']],
#  [['nlm', '530704']],
#  [['nia', '202174']],
#  [['nia', '472366']],
#  [['nimh', '679780']],
#  [['nida', '190642']],
#  [['nci', '125000']],
#  [['nidcd', '891718']],
#  [['nia', '182720']],
#  [['fic', '264813']],
#  [['fic', '165894']],
#  [['od', '1970897']],
#  [['ninds', '217794']],
#  [['nci', '151970']],
#  [['nida', '258794']],
#  [['niaid', '779012']],
#  [['nci', '1047754']],
#  [['nichd', '76000']],
#  [['nhlbi', '389222']],
#  [['nci', '164258']],
#  [['nccam', '5103'],
#   ['nci', '194059'],
#   ['nei', '30132'],
#   ['nhgri', '18636'],
#   ['nhlbi', '135364'],
#   ['nia', '70662'],
#   ['nidcd', '17806'],
#   ['niddk', '83772'],
#   ['nigms', '107559'],
#   ['ninds', '72617']],
#  [['nci', '45258'], ['nhlbi', '1095614']],
#  [['nidcd', '473676']],
#  [['nci', '149395']],
#  [['nigms', '280000']],
#  [['niehs', '154733']],
#  [['nimh', '176864']],
#  [['nei', '250000'], ['nhgri', '2950000'], ['nhlbi', '350000']],
#  [['nei', '384375']],
#  [['ninds', '370781']],
#  [['niaid', '197500']],
#  [['nichd', '122949']],
#  [['nigms', '555984']],
#  [['nia', '1862972']],
#  [['nigms', '220863']],
#  [['va', '320188']],
#  [['nhlbi', '673114']],
#  [['nhlbi', '698539']],
#  [['nigms', '492900']],
#  [['nhlbi', '250000'], ['niddk', '29730562']],
#  [['nida', '157235']],
#  [['od', '203850']],
#  [['niaid', '377544']],
#  [['nida', '186246']],
#  [['niddk', '559998']],
#  [['nigms', '583077']],
#  [['nci', '31559']],
#  [['nci', '13322']],
#  [['nichd', '330588']],
#  [['fic', '680000'], ['od', '140000']],
#  [['nichd', '341190']],
#  [['nimh', '232961'], ['ninds', '139776']],
#  [['niaid', '1238429']],
#  [['niaid', '125068']],
#  [['nan']],
#  [['nimh', '237398']],
#  [['niddk', '278445']],
#  [['nigms', '69791']],
#  [['fda', '829000']],
#  [['niaaa', '2404834']],
#  [['nigms', '379419']],
#  [['nhlbi', '148808']],
#  [['nci', '61664']],
#  [['nchhstp', '165535']],
#  [['nigms', '514696']],
#  [['nhlbi', '33041']],
#  [['nhlbi', '538896']],
#  [['niehs', '4737643']],
#  [['fic', '119213'], ['nimh', '100000']],
#  [['nhlbi', '224981']],
#  [['nhlbi', '673750']],
#  [['niaid', '2344519']],
#  [['nichd', '125566']],
#  [['niaid', '78291']],
#  [['nidcd', '328993']],
#  [['niehs', '544915']],
#  [['nidcd', '174585']],
#  [['cogh', '4939786']],
#  [['nci', '56118']],
#  [['niaaa', '341325']],
#  [['ninds', '602387']],
#  [['nci', '1000000'],
#   ['nhlbi', '2967184'],
#   ['nichd', '500000'],
#   ['niehs', '500000'],
#   ['od', '1200000']],
#  [['od', '300394']],
#  [['niaaa', '43576']],
#  [['nhlbi', '2622030']],
#  [['nidcd', '546473']],
#  [['niddk', '149472']],
#  [['nccih', '371025']],
#  [['nhlbi', '464337']],
#  [['niaid', '228000']],
#  [['niaaa', '29368']],
#  [['nci', '170618']],
#  [['niaid', '750000']],
#  [['nigms', '499305']],
#  [['nibib', '86502']],
#  [['niehs', '1443896']],
#  [['fic', '218797']],
#  [['ninds', '339063']],
#  [['ninds', '68948']],
#  [['ninds', '208384']],
#  [['nci', '1527281']],
#  [['nichd', '45337'], ['od', '450000']],
#  [['nigms', '90604']],
#  [['niaid', '620233']],
#  [['nichd', '77876'], ['od', '52539']],
#  [['nimh', '224872']],
#  [['niaid', '778371']],
#  [['nci', '861323']],
#  [['nhlbi', '29001']],
#  [['nci', '620252']],
#  [['nhlbi', '711878']],
#  [['nci', '179058']],
#  [['nigms', '56118']],
#  [['niddk', '343125']],
#  [['nhlbi', '1471491']],
#  [['nci', '100000']],
#  [['nimh', '186192']],
#  [['nia', '616985']],
#  [['nhlbi', '436411']],
#  [['nimh', '412531']],
#  [['nida', '338580']],
#  [['ninr', '282118']],
#  [['nci', '319550']],
#  [['nlm', '47008']],
#  [['nccih', '484353'], ['od', '248001']],
#  [['niehs', '126632']],
#  [['nimh', '278959']],
#  [['niaid', '517000']],
#  [['ninds', '43576']],
#  [['niddk', '34263']],
#  [['cdc', '1167749'], ['ncird', '700843']],
#  [['nei', '281750']],
#  [['nci', '372942']],
#  [['ninds', '230071']],
#  [['nhgri', '509510']],
#  [['niaaa', '129309']],
#  [['niaaa', '48749']],
#  [['niaid', '428640']],
#  [['nida', '245289']],
#  [['va', '124900']],
#  [['cogh', '200000']],
#  [['nida', '331522']],
#  [['nci', '346525']],
#  [['nei', '202503']],
#  [['nigms', '262135']],
#  [['nia', '121469']],
#  [['nci', '166337']],
#  [['nhlbi', '827237']],
#  [['nci', '63899']],
#  [['nimhd', '84568']],
#  [['niaid', '621129']],
#  [['nigms', '319950']],
#  [['nigms', '230406']],
#  [['niddk', '443875']],
#  [['niaid', '262500']],
#  [['niaid', '60446']],
#  [['nci', '469145'],
#   ['nei', '73141'],
#   ['niams', '23844'],
#   ['nidcr', '38040'],
#   ['niddk', '206027'],
#   ['nimh', '149598'],
#   ['ninr', '4680'],
#   ['od', '35525']],
#  [['niaid', '379485'], ['niams', '1']],
#  [['niams', '431970']],
#  [['nhlbi', '738217']],
#  [['cogh', '7690000']],
#  [['od', '240105']],
#  [['nimh', '232256']],
#  [['nhlbi', '744634']],
#  [['niehs', '495366']],
#  [['nigms', '543596']],
#  [['nichd', '315327']],
#  [['nimh', '127872']],
#  [['nimh', '248999']],
#  [['ninds', '4852363']],
#  [['nhlbi', '686342']],
#  [['nidcd', '353813']],
#  [['niaid', '567742']],
#  [['nci', '2446594']],
#  [['nigms', '12000']],
#  [['nci', '291600']],
#  [['ninds', '496324']],
#  [['ahrq', '249990']],
#  [['nei', '73151']],
#  [['nimh', '350620']],
#  [['niams', '292050']],
#  [['nhlbi', '807615']],
#  [['cdc', '1606621'], ['ncird', '1307070']],
#  [['nigms', '760254']],
#  [['ninds', '1716978']],
#  [['nigms', '90000']],
#  [['nci', '191067']],
#  [['nhlbi', '47190']],
#  [['niaid', '2068753']],
#  [['od', '92677']],
#  [['nci', '55721']],
#  [['nci', '323521']],
#  [['niaid', '4191765']],
#  [['niaid', '322862']],
#  [['ninds', '416217']],
#  [['nci', '369313']],
#  [['nigms', '401357']],
#  [['nigms', '529544']],
#  [['nia', '161750']],
#  [['nigms', '379780']],
#  [['cogh', '1300000']],
#  [['nigms', '634794']],
#  [['niaid', '330545']],
#  [['nimh', '360450']],
#  [['nci', '624643']],
#  [['nhlbi', '397500']],
#  [['nci', '375005']],
#  [['niddk', '327904']],
#  [['niaid', '438858']],
#  [['nci', '247249']],
#  [['ninr', '43576']],
#  [['nci', '185008']],
#  [['niaid', '286356']],
#  [['nida', '590098']],
#  [['ninds', '58522']],
#  [['nhlbi', '544214']],
#  [['nci', '160177']],
#  [['nigms', '211757']],
#  [['fic', '111608']],
#  [['nimh', '1616896']],
#  [['nidcd', '152000']],
#  [['niddk', '63513']],
#  [['nimh', '614796']],
#  [['nia', '274408']],
#  [['nci', '235177']],
#  [['ahrq', '34908']],
#  [['nan']],
#  [['nidcd', '154500']],
#  [['niddk', '163304']],
#  [['niddk', '336375']],
#  [['nichd', '18411']],
#  [['niehs', '767094']],
#  [['nigms', '2183550']],
#  [['nigms', '356610']],
#  [['nhlbi', '32107']],
#  [['nimh', '54294']],
#  [['nidcr', '750165']],
#  [['nigms', '289707']],
#  [['va', '92971']],
#  [['cogh', '7199537']],
#  [['niddk', '177465']],
#  [['nei', '279704']],
#  [['ninds', '333868']],
#  [['niaid', '416402']],
#  [['niddk', '176174']],
#  [['ninds', '552890']],
#  [['nigms', '191160']],
#  [['niddk', '353050']],
#  [['nci', '273732']],
#  [['niaid', '441044']],
#  [['nimh', '269000']],
#  [['cdc', '187000'], ['cogh', '3590712'], ['ncird', '1020000']],
#  [['nichd', '1349000']],
#  [['niddk', '151450']],
#  [['nhlbi', '122203']],
#  [['nhlbi', '451500']],
#  [['nhlbi', '422500']],
#  [['nci', '471755']],
#  [['niddk', '681927']],
#  [['nci', '928538']],
#  [['nci', '496003']],
#  [['nigms', '263891']],
#  [['nci', '202275']],
#  [['nida', '5000']],
#  [['nia', '331929']],
#  [['nimhd', '116666']],
#  [['nigms', '316006']],
#  [['nhlbi', '1702532'], ['nia', '146000'], ['niddk', '167600']],
#  [['nigms', '303270']],
#  [['nigms', '285533']],
#  [['nida', '1']],
#  [['nhlbi', '423750']],
#  [['nia', '116250']],
#  [['nimh', '527381']],
#  [['nei', '236427']],
#  [['niaid', '389410']],
#  [['od', '262395']],
#  [['cogh', '7177487']],
#  [['nhlbi', '380440']],
#  [['nimh', '180360']],
#  [['nccih', '166106']],
#  [['nhlbi', '385000']],
#  [['od', '231000']],
#  [['od', '185108']],
#  [['va', '150000']],
#  [['nigms', '189000']],
#  [['niaid', '373037']],
#  [['nia', '186875']],
#  [['ahrq', '431479']],
#  [['nhlbi', '376250']],
#  [['nida', '359685']],
#  [['niaid', '423750']],
#  [['nhlbi', '718362']],
#  [['nida', '209301']],
#  [['niddk', '48576']],
#  [['nan']],
#  [['ninds', '671299']],
#  [['niams', '380233']],
#  [['niehs', '158322']],
#  [['niaid', '487500']],
#  [['ninds', '292035']],
#  [['nigms', '298354']],
#  [['fic', '303762']],
#  [['nei', '80543']],
#  [['nia', '2410109']],
#  [['nigms', '294862']],
#  [['niddk', '419079']],
#  [['nci', '90794']],
#  [['niaid', '244816']],
#  [['nci', '56083']],
#  [['nci', '374359']],
#  [['nia', '680019']],
#  [['nia', '380715']],
#  [['nhlbi', '381250']],
#  [['niaaa', '366198']],
#  [['ninds', '40176']],
#  [['va', '87809']],
#  [['nimh', '391285']],
#  [['od', '159605']],
#  [['ninds', '42134']],
#  [['nia', '378775']],
#  [['nia', '840072']],
#  [['nhlbi', '397500']],
#  [['nhgri', '1189865']],
#  [['nci', '117418']],
#  [['niaid', '1921458']],
#  [['nigms', '109500']],
#  [['nhlbi', '373750']],
#  [['nichd', '598152']],
#  [['nidcd', '324063']],
#  [['ahrq', '149082']],
#  [['nia', '153300']],
#  [['niddk', '336725']],
#  [['ncats', '10000'], ['niams', '15000']],
#  [['ncipc', '400000']],
#  [['niehs', '388865']],
#  [['nichd', '564080']],
#  [['nimhd', '180373']],
#  [['nigms', '554414']],
#  [['nigms', '325850']],
#  [['niehs', '150635']],
#  [['ninds', '368970']],
#  [['ninds', '339817']],
#  [['ninds', '29869']],
#  [['cdc', '1433403'], ['ncird', '783317']],
#  [['ahrq', '432191']],
#  [['nigms', '112500']],
#  [['nigms', '303750']],
#  [['nci', '199553']],
#  [['niaid', '385420']],
#  [['nei', '41470']],
#  [['nci', '678786']],
#  [['nia', '538768']],
#  [['atsdr', '331895']],
#  [['niaaa', '173285']],
#  [['niaid', '249089']],
#  [['nhlbi', '134437']],
#  [['nei', '1054287']],
#  [['nimhd', '169120']],
#  [['niaid', '900000']],
#  [['nigms', '43576']],
#  [['niddk', '253776']],
#  [['niddk', '442238']],
#  [['nimh', '478538']],
#  [['niaid', '413019']],
#  [['niehs', '411176']],
#  [['nia', '246423']],
#  [['nida', '89410']],
#  [['nimh', '591194']],
#  [['nigms', '412510']],
#  [['nia', '75072']],
#  [['nimh', '274750']],
#  [['va', '269313']],
#  [['nigms', '288174']],
#  [['nci', '222125']],
#  [['nia', '625779']],
#  [['niehs', '900000']],
#  [['niaid', '54294']],
#  [['nci', '31690']],
#  [['nccih', '226860']],
#  [['niddk', '1']],
#  [['va', '136109']],
#  [['nigms', '327231']],
#  [['nhlbi', '483858']],
#  [['nci', '168563']],
#  [['niehs', '276636']],
#  [['niosh', '50000']],
#  [['nhlbi', '171612']],
#  [['niaaa', '311000'], ['nlm', '37832']],
#  [['ninds', '353739']],
#  [['nida', '10731']],
#  [['ahrq', '457899']],
#  [['nhlbi', '131417']],
#  [['nci', '48783']],
#  [['niaid', '200000']],
#  [['va', '150000']],
#  [['cogh', '1604908']],
#  [['nci', '144370'],
#   ['niaid', '2940584'],
#   ['nichd', '373497'],
#   ['nida', '72186']],
#  [['niaid', '288106']],
#  [['niddk', '458627']],
#  [['ninds', '348576']],
#  [['nimh', '184058']],
#  [['nci', '68181'], ['nhlbi', '68181'], ['niddk', '91638']],
#  [['niddk', '179388']],
#  [['nigms', '2257498']],
#  [['nhlbi', '832909']],
#  [['nichd', '12000'], ['niehs', '2000']],
#  [['nida', '725729']],
#  [['va', '261428']],
#  [['niaid', '1193904']],
#  [['nigms', '332817']],
#  [['nigms', '513312']],
#  [['niehs', '240804']],
#  [['cdc', '2974941'], ['ncird', '1167177']],
#  [['nci', '36301']],
#  [['nimh', '388750']],
#  [['nccih', '37000'], ['nci', '5000'], ['nida', '3000']],
#  [['niaid', '675404']],
#  [['niddk', '445350']],
#  [['nidcr', '40947']],
#  [['niaid', '564578']],
#  [['nci', '439144']],
#  [['nhlbi', '114173']],
#  [['niaid', '795962']],
#  [['nigms', '197878']],
#  [['nigms', '107088']],
#  [['niddk', '224665']],
#  [['niddk', '733811']],
#  [['niddk', '200000']],
#  [['nigms', '289787']],
#  [['niehs', '205908']],
#  [['nci', '4316453']],
#  [['nci', '288035']],
#  [['va', '99288']],
#  [['nidcd', '36097']],
#  [['nci', '526689']],
#  [['nci', '55996']],
#  [['niams', '660661']],
#  [['nia', '167069']],
#  [['niams', '214100']],
#  [['nci', '176481']],
#  [['nci', '527836']],
#  [['niaid', '193125']],
#  [['niddk', '638976']],
#  [['nccih', '316809']],
#  [['nhlbi', '170162']],
#  [['nhlbi', '632227']],
#  [['ninds', '255249']],
#  [['niddk', '738111']],
#  [['nimh', '814367']],
#  [['nidcd', '145453']],
#  [['ninds', '43788']],
#  [['niddk', '557787']],
#  [['ncats', '541417']],
#  [['nimh', '40116']],
#  [['nei', '344000']],
#  [['nigms', '62381']],
#  [['nci', '363342']],
#  [['od', '319653']],
#  [['niosh', '599998']],
#  [['nci', '54438']],
#  [['nci', '317423']],
#  [['nigms', '280536']],
#  [['nigms', '136905']],
#  [['ninds', '69789']],
#  [['nci', '74927']],
#  [['niaid', '311106']],
#  [['niaid', '256437']],
#  [['nigms', '2730000']],
#  [['nci', '75615']],
#  [['nigms', '292965']],
#  [['ninds', '1275463']],
#  [['niddk', '33677']],
#  [['nci', '392946']],
#  [['nigms', '75497']],
#  [['nci', '578258']],
#  [['nia', '200000']],
#  [['niaid', '193750']],
#  [['fic', '147893'], ['niehs', '74983']],
#  [['nia', '1017084']],
#  [['nigms', '341308']],
#  [['ninds', '351344']],
#  [['nichd', '278405']],
#  [['nida', '222750']],
#  [['niams', '168850']],
#  [['niddk', '143482']],
#  [['nia', '128412']],
#  [['nichd', '680507']],
#  [['nida', '332628']],
#  [['nei', '389432']],
#  [['nigms', '285385']],
#  [['nigms', '294500']],
#  [['nigms', '859472']],
#  [['nichd', '263788']],
#  [['nimh', '238404']],
#  [['nigms', '1031174']],
#  [['nimhd', '257720']],
#  [['niams', '1200284']],
#  [['nia', '145862']],
#  [['niaid', '161743']],
#  [['nigms', '219294']],
#  [['ninds', '43200']],
#  [['nida', '373568']],
#  [['niaid', '648325']],
#  [['nci', '972037']],
#  [['nei', '570993']],
#  [['niaid', '238218']],
#  [['nci', '358315']],
#  [['niaaa', '173813']],
#  [['nigms', '166693']],
#  [['nidcr', '381157']],
#  [['nci', '125544']],
#  [['nia', '988213']],
#  [['niehs', '1200000']],
#  [['niehs', '86277']],
#  [['nhlbi', '36423']],
#  [['nci', '684278']],
#  [['niddk', '500283']],
#  [['nigms', '359435']],
#  [['nigms', '797464']],
#  [['od', '730434']],
#  [['niddk', '349875']],
#  [['nidcd', '496927']],
#  [['niddk', '512978']],
#  [['fda', '959190']],
#  [['nhlbi', '169088']],
#  [['ncipc', '350000']],
#  [['ninds', '33498']],
#  [['fda', '300000']],
#  [['nci', '426720']],
#  [['nhlbi', '757536']],
#  [['nidcd', '54294']],
#  [['nida', '287863']],
#  [['od', '2280000']],
#  [['nhlbi', '747890']],
#  [['nida', '179055']],
#  [['nichd', '303525']],
#  [['nhlbi', '376250']],
#  [['niddk', '386441']],
#  [['ninds', '26960']],
#  [['niaid', '187500']],
#  [['nci', '1318190']],
#  [['nichd', '181912']],
#  [['niddk', '384975']],
#  [['ncats', '5000'], ['ninds', '15000']],
#  [['nhlbi', '157361']],
#  [['nimh', '496381']],
#  [['nci', '565669']],
#  [['nigms', '357532']],
#  [['nia', '201523']],
#  [['nigms', '248998']],
#  [['nci', '606395']],
#  [['nci', '918872']],
#  [['nci', '197779']],
#  [['niddk', '676318']],
#  [['nigms', '2035705']],
#  [['nidcd', '497070']],
#  [['nimh', '153963']],
#  [['nhlbi', '225861']],
#  [['nci', '68181'], ['nhlbi', '68181'], ['niddk', '136638']],
#  [['ahrq', '157248']],
#  [['nci', '170897']],
#  [['nei', '227125']],
#  [['niosh', '478040']],
#  [['nci', '77717']],
#  [['nci', '363713']],
#  [['nichd', '620069']],
#  [['nidcr', '40112']],
#  [['niams', '465050']],
#  [['nci', '206202']],
#  [['nidcr', '112500']],
#  [['nia', '239555']],
#  [['ncats', '226982']],
#  [['nigms', '120753']],
#  [['nci', '229791'],
#   ['ncmhd', '166667'],
#   ['nhlbi', '159125'],
#   ['nia', '26830'],
#   ['niaid', '703113'],
#   ['nichd', '72648'],
#   ['nida', '113540'],
#   ['niddk', '84280'],
#   ['nigms', '84280']],
#  [['nhlbi', '315363']],
#  [['nchhstp', '81911'], ['ncird', '100000']],
#  [['ninds', '33450']],
#  [['nci', '37384']],
#  [['nigms', '258899']],
#  [['nia', '1029425']],
#  [['nei', '241202']],
#  [['nichd', '957824']],
#  [['nhlbi', '382003']],
#  [['niams', '296010']],
#  [['niddk', '342000']],
#  [['niaid', '1036099']],
#  [['nidcr', '705106']],
#  [['nhlbi', '743914']],
#  [['nimhd', '403605']],
#  [['niams', '382800']],
#  [['od', '586944']],
#  [['nida', '490108']],
#  [['niddk', '59970']],
#  [['niddk', '156508']],
#  [['nci', '292725']],
#  [['nigms', '414133']],
#  [['nigms', '95308']],
#  [['nigms', '54294']],
#  [['nci', '534090']],
#  [['nichd', '178201']],
#  [['nci', '330527']],
#  [['niddk', '390062']],
#  [['ninr', '145922']],
#  [['nlm', '96990']],
#  [['nigms', '56118']],
#  [['nia', '90829']],
#  [['nei', '118732']],
#  [['nida', '351853']],
#  [['nigms', '523852']],
#  [['nci', '453878']],
#  [['nigms', '190603']],
#  [['niddk', '285473']],
#  [['nichd', '127451']],
#  [['niams', '204600']],
#  [['nigms', '482227']],
#  [['niams', '196680']],
#  [['nccdphp', '168800'], ['niosh', '6200']],
#  [['nchhstp', '247633']],
#  [['niddk', '383466']],
#  [['nidcr', '401739']],
#  [['ncipc', '349999']],
#  [['ninds', '577561']],
#  [['niddk', '359003']],
#  [['niaid', '185121']],
#  [['niddk', '591523']],
#  [['nidcr', '385000']],
#  [['niaaa', '578525']],
#  [['nci', '150298']],
#  [['nci', '82202']],
#  [['nia', '333125']],
#  [['nhlbi', '112350']],
#  [['nidcr', '154053']],
#  [['nci', '343404']],
#  [['ninds', '363126']],
#  [['ninds', '960000']],
#  [['nichd', '914581']],
#  [['niaid', '715308']],
#  [['nci', '614588']],
#  [['nci', '169792']],
#  [['nichd', '205488']],
#  [['nichd', '207810']],
#  [['nhlbi', '1373615']],
#  [['niaid', '77250']],
#  [['nigms', '47887']],
#  [['nia', '761685']],
#  [['nida', '347054']],
#  [['niddk', '364500']],
#  [['nidcd', '296951']],
#  [['nida', '631571']],
#  [['nci', '181613']],
#  [['ninds', '481392']],
#  [['nigms', '663254']],
#  [['nci', '171720']],
#  [['od', '56777']],
#  [['nigms', '355093']],
#  [['niaid', '789268']],
#  [['nhlbi', '1689433']],
#  [['nchhstp', '812385']],
#  [['nci', '455194'],
#   ['nhlbi', '325877'],
#   ['nia', '23448'],
#   ['niaid', '1926443'],
#   ['nichd', '96211'],
#   ['nida', '231045'],
#   ['niddk', '84280'],
#   ['nigms', '84280'],
#   ['nimh', '249856']],
#  [['ncats', '261845']],
#  [['nhlbi', '494739']],
#  [['nci', '1299901']],
#  [['nimh', '156436']],
#  [['nigms', '293418']],
#  [['niddk', '373500']],
#  [['ninds', '148554']],
#  [['nigms', '314360']],
#  [['niaaa', '536778']],
#  [['niddk', '332817']],
#  [['nccdphp', '50000']],
#  [['ahrq', '499999']],
#  [['nia', '772824']],
#  [['nia', '69476']],
#  [['niams', '696301']],
#  [['ninds', '41138']],
#  [['nhlbi', '426053']],
#  [['niehs', '335250']],
#  [['niams', '124310']],
#  [['nida', '249169']],
#  [['niehs', '111680']],
#  [['niaid', '397766']],
#  [['niddk', '584663']],
#  [['niaid', '148431']],
#  [['nibib', '193091']],
#  [['niaid', '727292']],
#  [['nci', '355887']],
#  [['nci', '69888']],
#  [['nichd', '74928']],
#  [['nhlbi', '445696']],
#  [['nigms', '288036']],
#  [['nhlbi', '591282']],
#  [['nan']],
#  [['nigms', '300000']],
#  [['nida', '80000']],
#  [['nci', '88411']],
#  [['nhlbi', '122250']],
#  [['niaid', '241000']],
#  [['nidcr', '135864']],
#  [['niddk', '448376']],
#  [['fda', '30000']],
#  [['nichd', '184387']],
#  [['nccih', '536248']],
#  [['nigms', '357232']],
#  [['nia', '241580']],
#  [['ninds', '183022']],
#  [['nci', '351450']],
#  [['nhgri', '1308268']],
#  [['niaaa', '74900']],
#  [['nhlbi', '352169']],
#  [['niaaa', '6708']],
#  [['niaid', '5800429']],
#  [['nigms', '131320']],
#  [['nccdphp', '205000']],
#  [['nci', '322663']],
#  [['od', '99998']],
#  [['nci', '512471']],
#  [['ncats', '326166']],
#  [['nimh', '385000']],
#  [['nci', '597516']],
#  [['nhgri', '149999']],
#  [['nci', '198151']],
#  [['nci', '329112']],
#  [['nia', '182468']],
#  [['nci', '517690']],
#  [['nigms', '494181']],
#  [['nci', '360837']],
#  [['nigms', '322377']],
#  [['nida', '46592'], ['nigms', '186368'], ['ninds', '93185']],
#  [['niaid', '2113282']],
#  [['nci', '694888']],
#  [['ninds', '56118']],
#  [['niaaa', '477936']],
#  [['nhlbi', '445872']],
#  [['nci', '201281']],
#  [['niehs', '112664']],
#  [['niaid', '1']],
#  [['nhlbi', '375445']],
#  [['niddk', '118800']],
#  [['nei', '214014']],
#  [['nigms', '296629']],
#  [['ninds', '430572']],
#  [['niaid', '371557']],
#  [['nia', '100606']],
#  [['nhlbi', '448222'], ['nigms', '320000']],
#  [['ninds', '1459432']],
#  [['nimh', '115258']],
#  [['niddk', '67436']],
#  [['niaid', '187308']],
#  [['nigms', '138054']],
#  [['nia', '249000']],
#  [['nichd', '344750']],
#  [['nhlbi', '449253']],
#  [['nimh', '126560']],
#  [['niams', '249000']],
#  [['nhlbi', '161578']],
#  [['nigms', '751732']],
#  [['ninds', '471665']],
#  [['nidcd', '381918']],
#  [['nhgri', '750000'], ['nigms', '500000'], ['od', '1250000']],
#  [['nci', '32938']],
#  [['nida', '165167']],
#  [['nida', '15336']],
#  [['ninds', '314880']],
#  [['niaaa', '330257']],
#  [['nchhstp', '269548']],
#  [['nci', '370500']],
#  [['nia', '675766']],
#  [['ninds', '418750']],
#  [['nci', '371942']],
#  [['fda', '378000']],
#  [['nigms', '314210']],
#  [['nimhd', '537492']],
#  [['cogh', '900000']],
#  [['va', '192202']],
#  [['nhlbi', '163912']],
#  [['nigms', '386688']],
#  [['nidcd', '537177']],
#  [['nidcd', '302742']],
#  [['ncats', '27000'],
#   ['nci', '13500'],
#   ['nichd', '14740'],
#   ['niddk', '13500'],
#   ['ninds', '13000'],
#   ['od', '13500']],
#  [['ahrq', '39085']],
#  [['niaid', '189059']],
#  [['niaid', '192764']],
#  [['fda', '16500']],
#  [['nibib', '132930']],
#  [['nida', '69677']],
#  [['nigms', '372500']],
#  [['niddk', '360000']],
#  [['nei', '461843']],
#  [['niaaa', '199273']],
#  [['nci', '603954']],
#  [['niddk', '33923']],
#  [['nimh', '760961']],
#  [['ninds', '328125']],
#  [['niams', '10000'], ['nigms', '320000']],
#  [['nimh', '387500']],
#  [['nibib', '1330268']],
#  [['nidcr', '621667']],
#  [['nia', '212340']],
#  [['nida', '457689']],
#  [['nci', '371327']],
#  [['niaaa', '499893']],
#  [['od', '171411']],
#  [['niaid', '475500']],
#  [['nci', '65466']],
#  [['niddk', '162000']],
#  [['nei', '328519']],
#  [['niddk', '167652']],
#  [['niehs', '916029']],
#  [['niams', '174900']],
#  [['nci', '2928248']],
#  [['niaaa', '8795'], ['nigms', '8795'], ['ninds', '8795']],
#  [['ninds', '331406']],
#  [['nia', '148062']],
#  [['nei', '472309']],
#  [['fda', '70000']],
#  [['nimh', '1447018']],
#  [['niaid', '974543']],
#  [['niehs', '954883']],
#  [['ninds', '319529']],
#  [['niehs', '390001']],
#  [['nimh', '117000']],
#  [['nigms', '266068']],
#  [['nccdphp', '450000']],
#  [['nci', '407932']],
#  [['nigms', '2741022']],
#  [['nida', '785992']],
#  [['niehs', '275481']],
#  [['nci', '841293']],
#  [['nci', '332000']],
#  [['niams', '1306306']],
#  [['nei', '383535']],
#  [['nichd', '1269762']],
#  [['ninr', '221415']],
#  [['od', '164171']],
#  [['nigms', '300889']],
#  [['nia', '224981']],
#  [['nhlbi', '497378']],
#  [['nigms', '323694']],
#  [['ninds', '347891']],
#  [['ninds', '43576']],
#  [['nci', '129512']],
#  [['nei', '516953']],
#  [['niddk', '122431']],
#  [['ninds', '560824']],
#  [['nhgri', '248999']],
#  [['nimh', '462334']],
#  [['nci', '115502']],
#  [['niams', '147420']],
#  [['cogh', '7500000']],
#  [['nigms', '339762']],
#  [['nigms', '361284']],
#  [['nhlbi', '645284']],
#  [['nhlbi', '349438']],
#  [['niams', '3000'], ['nidcr', '15000']],
#  [['nia', '158532']],
#  [['niehs', '179496']],
#  [['nlm', '510497']],
#  [['nci', '809152']],
#  [['ninds', '422219']],
#  [['niaid', '56118']],
#  [['nimh', '785660']],
#  [['nia', '162800']],
#  [['nci', '785005']],
#  [['od', '386411']],
#  [['nci', '232127']],
#  [['niddk', '339300']],
#  [['nichd', '27010']],
#  [['od', '523415']],
#  [['nigms', '350756']],
#  [['nei', '309920']],
#  [['nia', '2260643']],
#  [['nimh', '202500']],
#  [['nei', '500000']],
#  [['nci', '470355']],
#  [['nan']],
#  [['nichd', '249000']],
#  [['niddk', '514325']],
#  [['nimh', '526544']],
#  [['nigms', '47991']],
#  [['ninds', '330125']],
#  [['niddk', '716297']],
#  [['nimh', '452314']],
#  [['nibib', '94500']],
#  [['nigms', '833462']],
#  [['nci', '143992']],
#  [['niddk', '1162321']],
#  [['nci', '86607']],
#  [['fic', '149121']],
#  [['niddk', '389858']],
#  [['nigms', '60800']],
#  [['nichd', '561686']],
#  [['nigms', '213942']],
#  [['nidcd', '152000']],
#  [['nci', '186506']],
#  [['nei', '171299']],
#  [['va', '201894']],
#  [['niaid', '460185']],
#  [['nichd', '446321']],
#  [['nidcd', '207000']],
#  [['niaid', '381468']],
#  [['nhlbi', '486740']],
#  [['nan']],
#  [['nia', '805690']],
#  [['nigms', '303327']],
#  [['nhlbi', '354351']],
#  [['nci', '312142']],
#  [['niaid', '159553']],
#  [['od', '37228']],
#  [['nhlbi', '722453']],
#  [['nigms', '169648'], ['nimh', '84824'], ['ninds', '169649']],
#  [['nci', '78178']],
#  [['niddk', '223236']],
#  [['nimh', '521520']],
#  [['od', '845870']],
#  [['niaid', '473750']],
#  [['nidcr', '93927']],
#  [['nhlbi', '755925']],
#  [['nichd', '2423002'], ['ninds', '571242']],
#  [['niaid', '980060']],
#  [['nci', '983899']],
#  [['niaid', '2938698']],
#  [['niams', '760000']],
#  [['nigms', '332500']],
#  [['nci', '321793']],
#  [['ncats', '796396']],
#  [['niddk', '273274']],
#  [['nigms', '380868']],
#  [['nci', '893462']],
#  [['nci', '378220']],
#  [['niehs', '500000']],
#  [['nci', '64220'], ['niddk', '75000']],
#  [['niaid', '191875']],
#  [['nichd', '793888']],
#  [['niddk', '2000']],
#  [['niddk', '328558']],
#  [['nigms', '317750']],
#  [['nhlbi', '325521']],
#  [['ninds', '541141']],
#  [['nida', '422111']],
#  [['niaid', '56118']],
#  [['ncipc', '381115']],
#  [['niaid', '745405']],
#  [['ninds', '83515']],
#  [['nida', '538683']],
#  [['ninds', '608785']],
#  [['ninds', '341250']],
#  [['nhlbi', '540582']],
#  [['nigms', '190311']],
#  [['nidcr', '1'], ['od', '326471']],
#  [['ninds', '586541']],
#  [['nia', '5967418']],
#  [['dhhs', '1900000']],
#  [['nhgri', '847181']],
#  [['nci', '24402']],
#  [['nci', '308421']],
#  [['nigms', '409580']],
#  [['nci', '598790']],
#  [['nhlbi', '546726']],
#  [['niaid', '4043952']],
#  [['nccdphp', '1144500']],
#  [['niaid', '498399']],
#  [['nigms', '73334']],
#  [['niddk', '153683']],
#  [['nigms', '758950']],
#  [['nimh', '703720']],
#  [['nimh', '310695']],
#  [['nida', '314058']],
#  [['ninds', '329691']],
#  [['nimh', '177025']],
#  [['nidcr', '387500']],
#  [['niaid', '1353907']],
#  [['niaid', '359054']],
#  [['niddk', '300000']],
#  [['nimh', '385008']],
#  [['niddk', '159720']],
#  [['niaid', '402786']],
#  [['niddk', '238825']],
#  [['niaaa', '339750']],
#  [['nimh', '375971']],
#  [['nci', '1100000']],
#  [['niaaa', '684894']],
#  [['niddk', '331688']],
#  [['nigms', '244077']],
#  [['niehs', '1502489']],
#  [['niddk', '365143']],
#  [['niaaa', '221375']],
#  [['niaid', '582700']],
#  [['niaid', '882015']],
#  [['niddk', '476000']],
#  [['nichd', '238466']],
#  ...]

# %%
l = [item for sublist in ics for item in sublist]
institute_funds = pd.DataFrame(l, columns=['institute', 'funds'])
institute_funds['funds'] = institute_funds['funds'].astype(float)

# %% [markdown]
# Save to .csv

# %%
institute_funds.to_csv('institute_funds.csv', index = False, compression = 'gzip')
